# %%
import pandas as pd
import requests
import json
import glob
import itertools
import re

# %%
from sqlalchemy import create_engine

# %%
import plotly as py
import plotly.graph_objs as go
import plotly.express as px
py.io.renderers.default = 'browser'
# py.offline.init_notebook_mode(connected = True)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
url = 'https://www.dooinauction.com/public/search/?km_status=ing&current_page=1&records_per_page=100'
driver = webdriver.Chrome(executable_path='chromedriver.exe')
driver.get(url)
driver.implicitly_wait(30)
soup = BeautifulSoup(driver.page_source, 'lxml')
driver.close()
last = int(soup.find_all('a','page-link')[-2].text)
print(last)
# Out:
# C:\Users\DQ\AppData\Local\Temp/ipykernel_20520/2002846686.py:2: DeprecationWarning:
#
# executable_path has been deprecated, please pass in a Service object
# 135

# %%
data = pd.DataFrame()

for p in range(10):
    p+=1
    driver = webdriver.Chrome(executable_path='chromedriver.exe')
    url = f'https://www.dooinauction.com/public/search/?km_status=ing&current_page={p}&records_per_page=100'
    # url = f'https://www.dooinauction.com/auction/search/?km_status=ing&addr1%5B%5D=%EC%84%9C%EC%9A%B8&addr1%5B%5D=%EA%B2%BD%EA%B8%B0&current_page={p}&records_per_page=100'
    driver.get(url)
    print(url)
    driver.implicitly_wait(30)
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    
    items = soup.find_all("div","list-product")
    
    # if len(items) ==0:
    #     print("BREAK")
    #     break
        
    driver.close()
    df = pd.DataFrame()
    for i in items:
        d = pd.DataFrame()
        one = i.find_all('span',{'address-txt'})
        d['경매번호'] = [one[0].text.replace('지도 보기 ','')]
        d['주소지'] = [one[1].text]
        try:
            d['x'] = [(str(one[0]).split('urlX=')[1].split('&')[0])]
            d['y'] = [(str(one[0]).split('urlY=')[1].split('"')[0])]
        except IndexError:
            d['x'] = [""]
            d['y'] = [""]
        except ValueError:
            d['x'] = [""]
            d['y'] = [""]
        two = i.find_all('div',{'court-txt'})
        d['종류']  = [two[0].text]
        try:
            three = i.find_all(lambda tag: tag.name == 'div' and tag.get('class') == ['size-txt'])
            d['면적'] = [three[0].text]
        except IndexError:
            d['면적'] = ['']
        
        four = i.find_all('div','price-value')
        try:
            d['감정가'] = [int(four[0].text.replace(',',""))]
        except IndexError:
            d['감정가'] = [0]
        
        try:
            d['입찰가'] = [int(four[1].text.replace(',',""))]
        except IndexError:
            d['입찰가'] = [0]
        five = i.find_all('div', 'date-day')        
        d['입찰일'] = [five[0].text]
        df = df.append(d)
        
    data = data.append(df)
# Out:
# C:\Users\DQ\AppData\Local\Temp/ipykernel_20520/1300452974.py:5: DeprecationWarning:
#
# executable_path has been deprecated, please pass in a Service object
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=1&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=2&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=3&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=4&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=5&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=6&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=7&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=8&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=9&records_per_page=100
# https://www.dooinauction.com/public/search/?km_status=ing&current_page=10&records_per_page=100

# %%
data
# Out:
#                 경매번호                                                주소지  \
# 0   2020-0200-005513                         [기타 매각] 경기도 평택시 비전동 832 대지
# 0   2022-0800-036752     [기타 매각] 덕산온천관광호텔(충청남도 예산군 덕산면 사동리 482, 483 소재)
# 0   2022-0900-043841  [기타 매각] 충남 서산시 성연면 왕정리 719번지 이안서산테크노밸리 아파트 503...
# 0   2022-0900-043840  [기타 매각] 충남 서산시 성연면 왕정리 719번지 이안서산테크노밸리 아파트 503...
# 0   2022-0900-043839  [기타 매각] 충남 서산시 성연면 왕정리 719번지 이안서산테크노밸리 아파트 504...
# ..               ...                                                ...
# 0     2022-04041-004           [압류재산 매각] 전라남도 신안군 신의면 상태서리 38, 41-1, 42
# 0     2022-03964-003             [압류재산 매각] 광주광역시 북구 오치동  856-57, 856-58
# 0     2022-03958-001                      [압류재산 매각] 경상북도 경주시 서면 아화리 699
# 0     2022-03560-001  [압류재산 매각] 대구광역시 동구 지묘동 1386 엘에이치뉴웰시티 제301동 제4층...
# 0     2022-03505-002                   [압류재산 매각] 경상북도 예천군 풍양면 오지리 235-3
#
#                   x              y         종류 면적          감정가          입찰가  \
# 0   127.11165608151  36.9953608344         대지      2843346000   1768000000
# 0                 0              0  상가용및업무용건물     17156853860  15727572000
# 0                 0              0      주거용건물               0            0
# 0                 0              0      주거용건물               0            0
# 0                 0              0      주거용건물               0            0
# ..              ...            ...        ... ..          ...          ...
# 0                 0              0         토지        16830200     16831000
# 0                 0              0         토지        52360000     52360000
# 0                 0              0         토지        48430000     24215000
# 0                 0              0      주거용건물       323000000    258400000
# 0                 0              0         토지        12585972     12586000
#
#                    입찰일
# 0   2031.10.01 (14:00)
# 0   2022.11.24 (14:00)
# 0   2022.11.14 (10:00)
# 0   2022.11.14 (10:00)
# 0   2022.11.14 (10:00)
# ..                 ...
# 0   2022.10.24 (10:00)
# 0   2022.10.24 (10:00)
# 0   2022.10.24 (10:00)
# 0   2022.10.24 (10:00)
# 0   2022.10.24 (10:00)
#
# [1000 rows x 9 columns]

# %%
data['감정가'] = data['감정가'].str.replace(',','')

# %%
data['크기'] = 10

data['x'] = pd.to_numeric(data['x'],errors='coerce')
data['y'] = pd.to_numeric(data['y'],errors='coerce')

# data['감정가']=data['감정가'].apply(lambda x : "{:,}".format(x))
# data['입찰가']=data['입찰가'].apply(lambda x : "{:,}".format(x))

data['감정가'] = pd.to_numeric(data['감정가'],errors='coerce')
data['입찰가'] = pd.to_numeric(data['입찰가'],errors='coerce')

data['감정가']=data['감정가'].apply("{:,}".format)
data['입찰가']=data['입찰가'].apply("{:,}".format)

# %%
px.set_mapbox_access_token("pk.eyJ1IjoidGl2bWU3IiwiYSI6ImNrMWEwZDVtNDI4Zm4zYm1vY3o3Z25zejEifQ._yTPkj3nXTzor72zIevLCQ")
hover = [x for x in ['경매번호','주소지','종류','면적','감정가','입찰가','입찰일'] if x in data.columns]
fig = px.scatter_mapbox(data, lat="y", lon="x", hover_name="주소지",zoom = 6, hover_data = hover,color='종류',size = '크기')
fig.update_traces(visible='legendonly', selector=dict(type='scattermapbox'))
# fig.update_layout(autosize=True,width=1500,height=750)
# fname = input("파일명: ") + ".html"
# py.offline.plot(fig,filename=fname)
fig.write_html(input('파일명: ') + ".html",auto_open = False)
fig.show()
# Out:
# 파일명:  전국

# %%
data[data['종류'].str.contains("아파트")]
# Out:
#                 경매번호                                           주소지  \
# 0       2021 타경 2308           대구 달성군 현풍면 원교리 103 주공아파트 7동 5층 501호
# 0       2021 타경 2371           서울 관악구 봉천동 1574-1 생모리츠타운 11층 아1102호
# 0       2021 타경 2888        경북 경주시 용강동 1291-3 보우근화아파트 605동 5층 601호
# 0       2021 타경 3400           대구 달서구 장기동 809 영남네오빌파크 101동 2층 205호
# 0       2021 타경 3533             경북 칠곡군 북삼읍 어로리 440-1 105동 5층 509호
# ..               ...                                           ...
# 0   2022 타경 31769(2)       전북 전주시 완산구 서신동 962-2 중흥아파트 106동 9층 907호
# 0      2022 타경 32182    전북 완주군 봉동읍 낙평리 47 봉동한신2차아파트 202동 11층 1101호
# 0      2022 타경 32342  전북 전주시 완산구 서신동 961 서신동동아한일아파트 108동 12층 1205호
# 0      2022 타경 32779    전북 완주군 고산면 읍내리 973 고산동우더리치아파트 104동 9층 902호
# 0    2021 타경 6776(4)           광주 북구 운암동 68 벽산블루밍메가씨티 203동 4층 401호
#
#              x          y   종류                                      면적  \
# 0   128.444071  35.692436  아파트  건물 39.72㎡(12.02평) / 대지권 50.61㎡(15.31평)
# 0   126.947724  37.478919  아파트    건물 63.99㎡(19.36평) / 대지권 16.9㎡(5.11평)
# 0   129.226964  35.873093  아파트   건물 65.88㎡(19.93평) / 대지권 47.1㎡(14.25평)
# 0   128.526253  35.847606  아파트    건물 122.99㎡(37.2평) / 대지권 69.1㎡(20.9평)
# 0   128.335033  36.045608  아파트   건물 59.97㎡(18.14평) / 대지권 50.3㎡(15.22평)
# ..         ...        ...  ...                                     ...
# 0   127.114609  35.834794  아파트    건물 59.96㎡(18.14평) / 대지권 31.8㎡(9.62평)
# 0   127.166051  35.934667  아파트     건물 59.93㎡(18.13평) / 대지권 35㎡(10.59평)
# 0   127.117782  35.836345  아파트    건물 59.93㎡(18.13평) / 대지권 31.6㎡(9.56평)
# 0   127.212606  35.975248  아파트   건물 59.78㎡(18.08평) / 대지권 63.4㎡(19.18평)
# 0   126.876795  35.174612  아파트  건물 120.61㎡(36.48평) / 대지권 47.7㎡(14.43평)
#
#             감정가          입찰가         입찰일  크기
# 0    57,000,000   57,000,000  2022-08-09  10
# 0   505,000,000  505,000,000  2022-08-09  10
# 0   105,000,000  105,000,000  2022-08-09  10
# 0   581,000,000  581,000,000  2022-08-09  10
# 0    29,000,000   14,210,000  2022-08-09  10
# ..          ...          ...         ...  ..
# 0   186,000,000  130,200,000  2022-10-17  10
# 0    65,000,000   45,500,000  2022-10-17  10
# 0   179,000,000  125,300,000  2022-10-17  10
# 0   135,000,000  135,000,000  2022-10-17  10
# 0   577,000,000  323,120,000  2022-10-27  10
#
# [1487 rows x 10 columns]

# %%
data.to_csv(input('file name: ')+".csv",encoding ='euc_kr',index=False)
# Out:
# file name:  data

# %%
con = create_engine("postgresql://czbfzixfsuskvz:704257ac35e9181b5ca631958d5e298e3fc71806bbfb49e00e5a9db561e6ef32@ec2-44-197-128-108.compute-1.amazonaws.com:5432/d2iua2i1fvjmug")

# %%
data.to_sql('dooin',con,if_exists = 'replace',index=False)
